# %%
import numpy as np
import random
class Cube:
    def __init__(self):
        self._u = np.matrix([['🟨', '🟨'], ['🟨', '🟨']], dtype = 'str')      
        self._d = np.matrix([['⬜', '⬜'], ['⬜', '⬜']], dtype = 'str')     
        self._f = np.matrix([['🟩', '🟩'], ['🟩', '🟩']], dtype = 'str')
        self._b = np.matrix([['🟦', '🟦'], ['🟦', '🟦']], dtype = 'str')
        self._r = np.matrix([['🟧', '🟧'], ['🟧', '🟧']], dtype = 'str')
        self._l = np.matrix([['🟥', '🟥'], ['🟥', '🟥']], dtype = 'str')
    
    
    def __repr__(self):
        outstr = ''
        for i in range(2):
            outstr += '   '
            for j in range(2):
                outstr += self._u[i,j]
            outstr += '\n'
        
        for i in range(2):
            for j in range(2):
                outstr += self._l[i, j]
            for j in range(2):
                outstr += self._f[i, j]
            for j in range(2):
                outstr += self._r[i, j]
                
            outstr += '\t'
            for j in range(2):
                outstr += self._b[i, j]
            outstr += '\n'
            
        for i in range(2):
            outstr += '   '
            for j in range(2):
                outstr += self._d[i,j]
            outstr += '\n'
        
        return outstr

    
    # 2 = double move, 3 = counter-clockwise move
    def move(self, mv, modifier = 1):
        for i in range(modifier):
            mv()
    
    
    # Turns layer 90 degrees clockwise with respect to the face.
    def U(self):
        temp = self._l[0].copy()
        self._l[0] = self._f[0]
        self._f[0] = self._r[0]
        self._r[0] = self._b[0]
        self._b[0] = temp
        self._u = np.rot90(self._u, 3)

        
    def D(self):
        temp = self._f[1].copy()
        self._f[1] = self._l[1]
        self._l[1] = self._b[1]
        self._b[1] = self._r[1]
        self._r[1] = temp
        self._d = np.rot90(self._d, 3)        
        
    
    def F(self):
        temp = self._u[1,:].copy()
        self._u[1,:] = np.flip(np.transpose(self._l[:,1]), axis = 1)
        self._l[:,1] = np.flip(np.transpose(self._d[0,:]), axis = 1)
        self._d[0,:] = np.flip(np.transpose(self._r[:,0]), axis = 1)
        self._r[:,0] = np.flip(np.transpose(temp), axis = 1)
        self._f = np.rot90(self._f, 3)
        
        
    #broken
    def B(self):
        temp = self._d[0,:].copy()
        self._u[0,:] = np.transpose(self._r[:,0])
        self._l[:,0] = np.transpose(self._u[1,:])
        self._d[1,:] = np.transpose(self._l[:,1])
        self._r[:,1] = np.transpose(temp)
        self._b = np.rot90(self._b, 3)
        
        
    def R(self):
        temp = self._u[:,1].copy()
        self._u[:,1] = self._f[:,1]
        self._f[:,1] = self._d[:,1]
        self._d[:,1] = np.flip(self._b[:,0], axis=0)
        self._b[:,0] = temp[::-1]    
        self._r = np.rot90(self._r, 3)
        
        
    def L(self):
        temp = self._d[:,0].copy()
        self._d[:,0] = self._f[:,0]
        self._f[:,0] = self._u[:,0]
        self._u[:,0] = np.flip(self._b[:,1], axis=0)
        self._b[:,1] = temp[::-1]    
        self._l = np.rot90(self._l, 3)
    
    
    #rotates whole cube along the Y axis
    def Y(self):
        self.U()
        self.move(self.D, 3)
        
        
    def scramble(self, length):
        print_str = 'Your scramble: (Z2) '
        modifiers =({"1" : "", "2" : "2", "3" : "\'"})
        move = ''  
        prev = ''
        for i in range(length):        
            modifier = random.choice(list(modifiers.keys()))
            while move == prev:
                move = random.choice(['r', 'u', 'f'])
            prev = move
            
            if move == 'r':
                self.move(self.R, int(modifier))
            elif move == 'u':
                self.move(self.U, int(modifier))
            elif move == 'f':
                self.move(self.F, int(modifier))
                
            print_str += move.upper() + modifiers[modifier] + " "
            
        print(print_str)

# %%
class main:
    cube = Cube()
    print(cube)
    cube.scramble(10)
    print(cube)

    choice = str.lower(input("Choose a move >>> "))
    while(not choice == '0'):
        if len(choice) == 2:
            if choice[len(choice)-1] == '\'':
                modifier = 3
            elif choice[len(choice)-1] == '2':
                modifier = 2
        else:
            modifier = 1

        if choice[0] == 'u':
            cube.move(cube.U, modifier)
        elif choice[0] == 'd':
            cube.move(cube.D, modifier)
        elif choice[0] == 'f':
            cube.move(cube.F, modifier)
        elif choice[0] == 'b':
            cube.move(cube.B, modifier)
        elif choice[0] == 'r':
            cube.move(cube.R, modifier)
        elif choice[0] == 'l':
            cube.move(cube.L, modifier)
        elif choice[0] == 'y':
            cube.move(cube.Y, modifier)

        print(cube)
        choice = str.lower(input("Chose a move >>> "))
# Out:
#    🟨🟨
#    🟨🟨
# 🟥🟥🟩🟩🟧🟧	🟦🟦
# 🟥🟥🟩🟩🟧🟧	🟦🟦
#    ⬜⬜
#    ⬜⬜
#
# Your scramble: (Z2) U' R' U2 R2 F' R' U2 F' R' F
#    🟨🟥
#    🟧🟧
# 🟩🟦🟨🟨🟩⬜	🟩🟥
# 🟥🟦🟨🟧⬜🟧	🟦🟦
#    🟥🟩
#    ⬜⬜
#
# Choose a move >>> u
#    🟧🟨
#    🟧🟥
# 🟨🟨🟩⬜🟩🟥	🟩🟦
# 🟥🟦🟨🟧⬜🟧	🟦🟦
#    🟥🟩
#    ⬜⬜
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 class main:
#       2     cube = Cube()
#       3     print(cube)
#
# Input In [4], in main()
#      30     cube.move(cube.Y, modifier)
#      32 print(cube)
# ---> 33 choice = str.lower(input("Chose a move >>> "))
#
# File ~/cs4795/jupyterenv/lib/python3.8/site-packages/ipykernel/kernelbase.py:1062, in Kernel.raw_input(self, prompt)
#    1058 if not self._allow_stdin:
#    1059     raise StdinNotImplementedError(
#    1060         "raw_input was called, but this frontend does not support input requests."
#    1061     )
# -> 1062 return self._input_request(
#    1063     str(prompt),
#    1064     self._parent_ident["shell"],
#    1065     self.get_parent("shell"),
#    1066     password=False,
#    1067 )
#
# File ~/cs4795/jupyterenv/lib/python3.8/site-packages/ipykernel/kernelbase.py:1107, in Kernel._input_request(self, prompt, ident, parent, password)
#    1104             break
#    1105 except KeyboardInterrupt:
#    1106     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1107     raise KeyboardInterrupt("Interrupted by user") from None
#    1108 except Exception:
#    1109     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
